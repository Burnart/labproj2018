# %%
import os
import sys
import random
import warnings

import tensorflow as tf
from tensorflow import keras

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K

# %% [markdown]
# PARAMETER SETTINGS

# %%
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = '../input/stage1_train/'
TEST_PATH = '../input/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in enumerate(train_ids):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in enumerate(test_ids):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# Getting and resizing test images ...
# Done!

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
plt.figure()
plt.imshow(X_train[1])
plt.colorbar()
plt.gca().grid(False)

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# /home/mb/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/mb/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = keras.layers.Lambda(lambda x: x / 255) (inputs)

# %%
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (s)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 8)  224         lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 8)  584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 16)   1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 128)    73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   32832       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 128)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   73792       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 32)   8224        conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 16)   2064        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 32)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 8)  520         conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 16) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 8)  1160        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 8)  584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 485,817
# Trainable params: 485,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=8, epochs=30, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 63s 105ms/step - loss: 0.4902 - val_loss: 0.4091
#
# Epoch 00001: val_loss improved from inf to 0.40908, saving model to model-dsbowl2018-1.h5
# Epoch 2/30
# 603/603 [==============================] - 59s 97ms/step - loss: 0.3111 - val_loss: 0.2704
#
# Epoch 00002: val_loss improved from 0.40908 to 0.27042, saving model to model-dsbowl2018-1.h5
# Epoch 3/30
# 603/603 [==============================] - 62s 103ms/step - loss: 0.1994 - val_loss: 0.1860
#
# Epoch 00003: val_loss improved from 0.27042 to 0.18598, saving model to model-dsbowl2018-1.h5
# Epoch 4/30
# 603/603 [==============================] - 57s 95ms/step - loss: 0.1333 - val_loss: 0.1308
#
# Epoch 00004: val_loss improved from 0.18598 to 0.13079, saving model to model-dsbowl2018-1.h5
# Epoch 5/30
# 603/603 [==============================] - 58s 96ms/step - loss: 0.1132 - val_loss: 0.1178
#
# Epoch 00005: val_loss improved from 0.13079 to 0.11782, saving model to model-dsbowl2018-1.h5
# Epoch 6/30
# 603/603 [==============================] - 58s 96ms/step - loss: 0.1027 - val_loss: 0.1064
#
# Epoch 00006: val_loss improved from 0.11782 to 0.10642, saving model to model-dsbowl2018-1.h5
# Epoch 7/30
# 603/603 [==============================] - 55s 90ms/step - loss: 0.0936 - val_loss: 0.0986
#
# Epoch 00007: val_loss improved from 0.10642 to 0.09859, saving model to model-dsbowl2018-1.h5
# Epoch 8/30
# 603/603 [==============================] - 58s 96ms/step - loss: 0.0970 - val_loss: 0.0986
#
# Epoch 00008: val_loss did not improve from 0.09859
# Epoch 9/30
# 603/603 [==============================] - 60s 99ms/step - loss: 0.0934 - val_loss: 0.0999
#
# Epoch 00009: val_loss did not improve from 0.09859
# Epoch 10/30
# 603/603 [==============================] - 57s 94ms/step - loss: 0.0913 - val_loss: 0.0936
#
# Epoch 00010: val_loss improved from 0.09859 to 0.09356, saving model to model-dsbowl2018-1.h5
# Epoch 11/30
# 603/603 [==============================] - 57s 94ms/step - loss: 0.0862 - val_loss: 0.0944
#
# Epoch 00011: val_loss did not improve from 0.09356
# Epoch 12/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0827 - val_loss: 0.0968
#
# Epoch 00012: val_loss did not improve from 0.09356
# Epoch 13/30
# 603/603 [==============================] - 56s 92ms/step - loss: 0.0835 - val_loss: 0.0922
#
# Epoch 00013: val_loss improved from 0.09356 to 0.09215, saving model to model-dsbowl2018-1.h5
# Epoch 14/30
# 603/603 [==============================] - 55s 90ms/step - loss: 0.0832 - val_loss: 0.1636
#
# Epoch 00014: val_loss did not improve from 0.09215
# Epoch 15/30
# 603/603 [==============================] - 55s 92ms/step - loss: 0.1012 - val_loss: 0.0958
#
# Epoch 00015: val_loss did not improve from 0.09215
# Epoch 16/30
# 603/603 [==============================] - 59s 98ms/step - loss: 0.0820 - val_loss: 0.0905
#
# Epoch 00016: val_loss improved from 0.09215 to 0.09054, saving model to model-dsbowl2018-1.h5
# Epoch 17/30
# 603/603 [==============================] - 62s 102ms/step - loss: 0.0813 - val_loss: 0.0905
#
# Epoch 00017: val_loss improved from 0.09054 to 0.09049, saving model to model-dsbowl2018-1.h5
# Epoch 18/30
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0808 - val_loss: 0.0926
#
# Epoch 00018: val_loss did not improve from 0.09049
# Epoch 19/30
# 603/603 [==============================] - 61s 101ms/step - loss: 0.0806 - val_loss: 0.0842
#
# Epoch 00019: val_loss improved from 0.09049 to 0.08420, saving model to model-dsbowl2018-1.h5
# Epoch 20/30
# 603/603 [==============================] - 61s 101ms/step - loss: 0.0786 - val_loss: 0.0925
#
# Epoch 00020: val_loss did not improve from 0.08420
# Epoch 21/30
# 603/603 [==============================] - 59s 98ms/step - loss: 0.0765 - val_loss: 0.0877
#
# Epoch 00021: val_loss did not improve from 0.08420
# Epoch 22/30
# 603/603 [==============================] - 70s 116ms/step - loss: 0.0764 - val_loss: 0.0837
#
# Epoch 00022: val_loss improved from 0.08420 to 0.08370, saving model to model-dsbowl2018-1.h5
# Epoch 23/30
# 603/603 [==============================] - 61s 101ms/step - loss: 0.0767 - val_loss: 0.0815
#
# Epoch 00023: val_loss improved from 0.08370 to 0.08149, saving model to model-dsbowl2018-1.h5
# Epoch 24/30
# 603/603 [==============================] - 58s 96ms/step - loss: 0.0756 - val_loss: 0.0842
#
# Epoch 00024: val_loss did not improve from 0.08149
# Epoch 25/30
# 603/603 [==============================] - 64s 107ms/step - loss: 0.0745 - val_loss: 0.0813
#
# Epoch 00025: val_loss improved from 0.08149 to 0.08127, saving model to model-dsbowl2018-1.h5
# Epoch 26/30
# 603/603 [==============================] - 63s 104ms/step - loss: 0.0737 - val_loss: 0.0818
#
# Epoch 00026: val_loss did not improve from 0.08127
# Epoch 27/30
# 603/603 [==============================] - 58s 96ms/step - loss: 0.0728 - val_loss: 0.0792
#
# Epoch 00027: val_loss improved from 0.08127 to 0.07923, saving model to model-dsbowl2018-1.h5
# Epoch 28/30
# 603/603 [==============================] - 63s 105ms/step - loss: 0.0721 - val_loss: 0.0791
#
# Epoch 00028: val_loss improved from 0.07923 to 0.07912, saving model to model-dsbowl2018-1.h5
# Epoch 29/30
# 603/603 [==============================] - 55s 92ms/step - loss: 0.0734 - val_loss: 0.0799
#
# Epoch 00029: val_loss did not improve from 0.07912
# Epoch 30/30
# 603/603 [==============================] - 55s 91ms/step - loss: 0.0721 - val_loss: 0.0821
#
# Epoch 00030: val_loss did not improve from 0.07912

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 18s 30ms/step
# 67/67 [==============================] - 2s 28ms/step
# 65/65 [==============================] - 2s 29ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# /home/mb/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/mb/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
import cv2 as cv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-9458db612e9e> in <module>()
# ----> 1 import cv2 as cv
#
# ModuleNotFoundError: No module named 'cv2'
