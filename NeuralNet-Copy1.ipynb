# %%
import os
import sys
import random
import warnings


import tensorflow as tf
from tensorflow import keras
#from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/mb/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from subprocess import check_output

from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

# %% [raw]
# PARAMETER SETTINGS

# %%
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = '../input/stage1_train/'
TEST_PATH = '../input/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in enumerate(train_ids):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in enumerate(test_ids):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# Getting and resizing test images ...
# Done!

# %%
plt.figure()
plt.imshow(X_train[0])
plt.colorbar()
plt.gca().grid(False)

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# /home/mb/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/mb/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K

# %%
from tensorflow.metrics import mean_iou

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = keras.layers.Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (s)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 8)  224         lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 8)  584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 16)   1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 128)    73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   32832       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 128)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   73792       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 32)   8224        conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 16)   2064        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 32)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 8)  520         conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 16) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 8)  1160        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 8)  584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 485,817
# Trainable params: 485,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-2.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=8, epochs=30, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/30
# 603/603 [==============================] - 63s 105ms/step - loss: 0.4909 - mean_iou: 0.4199 - val_loss: 0.3737 - val_mean_iou: 0.4241
#
# Epoch 00001: val_loss improved from inf to 0.37366, saving model to model-dsbowl2018-2.h5
# Epoch 2/30
# 603/603 [==============================] - 63s 105ms/step - loss: 0.2926 - mean_iou: 0.4233 - val_loss: 0.2715 - val_mean_iou: 0.4238
#
# Epoch 00002: val_loss improved from 0.37366 to 0.27149, saving model to model-dsbowl2018-2.h5
# Epoch 3/30
# 603/603 [==============================] - 57s 94ms/step - loss: 0.2023 - mean_iou: 0.4443 - val_loss: 0.1851 - val_mean_iou: 0.4785
#
# Epoch 00003: val_loss improved from 0.27149 to 0.18509, saving model to model-dsbowl2018-2.h5
# Epoch 4/30
# 603/603 [==============================] - 59s 98ms/step - loss: 0.1585 - mean_iou: 0.5090 - val_loss: 0.1679 - val_mean_iou: 0.5353
#
# Epoch 00004: val_loss improved from 0.18509 to 0.16787, saving model to model-dsbowl2018-2.h5
# Epoch 5/30
# 603/603 [==============================] - 61s 100ms/step - loss: 0.1230 - mean_iou: 0.5568 - val_loss: 0.1256 - val_mean_iou: 0.5792
#
# Epoch 00005: val_loss improved from 0.16787 to 0.12558, saving model to model-dsbowl2018-2.h5
# Epoch 6/30
# 603/603 [==============================] - 59s 98ms/step - loss: 0.1083 - mean_iou: 0.5980 - val_loss: 0.1093 - val_mean_iou: 0.6148
#
# Epoch 00006: val_loss improved from 0.12558 to 0.10930, saving model to model-dsbowl2018-2.h5
# Epoch 7/30
# 603/603 [==============================] - 59s 98ms/step - loss: 0.1012 - mean_iou: 0.6291 - val_loss: 0.1060 - val_mean_iou: 0.6416
#
# Epoch 00007: val_loss improved from 0.10930 to 0.10602, saving model to model-dsbowl2018-2.h5
# Epoch 8/30
# 603/603 [==============================] - 57s 94ms/step - loss: 0.1013 - mean_iou: 0.6519 - val_loss: 0.1061 - val_mean_iou: 0.6619
#
# Epoch 00008: val_loss did not improve from 0.10602
# Epoch 9/30
# 603/603 [==============================] - 59s 98ms/step - loss: 0.0928 - mean_iou: 0.6705 - val_loss: 0.1055 - val_mean_iou: 0.6791
#
# Epoch 00009: val_loss improved from 0.10602 to 0.10554, saving model to model-dsbowl2018-2.h5
# Epoch 10/30
# 603/603 [==============================] - 58s 96ms/step - loss: 0.0916 - mean_iou: 0.6863 - val_loss: 0.1058 - val_mean_iou: 0.6932
#
# Epoch 00010: val_loss did not improve from 0.10554
# Epoch 11/30
# 603/603 [==============================] - 59s 99ms/step - loss: 0.0966 - mean_iou: 0.6993 - val_loss: 0.0960 - val_mean_iou: 0.7045
#
# Epoch 00011: val_loss improved from 0.10554 to 0.09602, saving model to model-dsbowl2018-2.h5
# Epoch 12/30
# 603/603 [==============================] - 61s 102ms/step - loss: 0.0861 - mean_iou: 0.7099 - val_loss: 0.0930 - val_mean_iou: 0.7151
#
# Epoch 00012: val_loss improved from 0.09602 to 0.09302, saving model to model-dsbowl2018-2.h5
# Epoch 13/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0852 - mean_iou: 0.7197 - val_loss: 0.0895 - val_mean_iou: 0.7242
#
# Epoch 00013: val_loss improved from 0.09302 to 0.08950, saving model to model-dsbowl2018-2.h5
# Epoch 14/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0824 - mean_iou: 0.7289 - val_loss: 0.1069 - val_mean_iou: 0.7327
#
# Epoch 00014: val_loss did not improve from 0.08950
# Epoch 15/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0883 - mean_iou: 0.7359 - val_loss: 0.0898 - val_mean_iou: 0.7390
#
# Epoch 00015: val_loss did not improve from 0.08950
# Epoch 16/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0821 - mean_iou: 0.7421 - val_loss: 0.0917 - val_mean_iou: 0.7452
#
# Epoch 00016: val_loss did not improve from 0.08950
# Epoch 17/30
# 603/603 [==============================] - 56s 92ms/step - loss: 0.0809 - mean_iou: 0.7479 - val_loss: 0.0850 - val_mean_iou: 0.7509
#
# Epoch 00017: val_loss improved from 0.08950 to 0.08500, saving model to model-dsbowl2018-2.h5
# Epoch 18/30
# 603/603 [==============================] - 57s 95ms/step - loss: 0.0809 - mean_iou: 0.7536 - val_loss: 0.0906 - val_mean_iou: 0.7560
#
# Epoch 00018: val_loss did not improve from 0.08500
# Epoch 19/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0796 - mean_iou: 0.7586 - val_loss: 0.0950 - val_mean_iou: 0.7608
#
# Epoch 00019: val_loss did not improve from 0.08500
# Epoch 20/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0800 - mean_iou: 0.7630 - val_loss: 0.0885 - val_mean_iou: 0.7650
#
# Epoch 00020: val_loss did not improve from 0.08500
# Epoch 21/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0755 - mean_iou: 0.7670 - val_loss: 0.0897 - val_mean_iou: 0.7690
#
# Epoch 00021: val_loss did not improve from 0.08500
# Epoch 22/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0794 - mean_iou: 0.7706 - val_loss: 0.0843 - val_mean_iou: 0.7724
#
# Epoch 00022: val_loss improved from 0.08500 to 0.08430, saving model to model-dsbowl2018-2.h5
# Epoch 23/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0769 - mean_iou: 0.7741 - val_loss: 0.0796 - val_mean_iou: 0.7758
#
# Epoch 00023: val_loss improved from 0.08430 to 0.07959, saving model to model-dsbowl2018-2.h5
# Epoch 24/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0750 - mean_iou: 0.7775 - val_loss: 0.0780 - val_mean_iou: 0.7791
#
# Epoch 00024: val_loss improved from 0.07959 to 0.07799, saving model to model-dsbowl2018-2.h5
# Epoch 25/30
# 603/603 [==============================] - 56s 94ms/step - loss: 0.0732 - mean_iou: 0.7807 - val_loss: 0.0786 - val_mean_iou: 0.7822
#
# Epoch 00025: val_loss did not improve from 0.07799
# Epoch 26/30
# 603/603 [==============================] - 56s 92ms/step - loss: 0.0721 - mean_iou: 0.7836 - val_loss: 0.0752 - val_mean_iou: 0.7851
#
# Epoch 00026: val_loss improved from 0.07799 to 0.07518, saving model to model-dsbowl2018-2.h5
# Epoch 27/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0735 - mean_iou: 0.7865 - val_loss: 0.0847 - val_mean_iou: 0.7878
#
# Epoch 00027: val_loss did not improve from 0.07518
# Epoch 28/30
# 603/603 [==============================] - 56s 92ms/step - loss: 0.0754 - mean_iou: 0.7890 - val_loss: 0.0786 - val_mean_iou: 0.7901
#
# Epoch 00028: val_loss did not improve from 0.07518
# Epoch 29/30
# 603/603 [==============================] - 56s 93ms/step - loss: 0.0724 - mean_iou: 0.7912 - val_loss: 0.0795 - val_mean_iou: 0.7924
#
# Epoch 00029: val_loss did not improve from 0.07518
# Epoch 30/30
# 603/603 [==============================] - 56s 92ms/step - loss: 0.0724 - mean_iou: 0.7935 - val_loss: 0.0753 - val_mean_iou: 0.7945
#
# Epoch 00030: val_loss did not improve from 0.07518

# %% [markdown]
# Mean IoU metric

# %%
X_test[3018]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-addac7b66c77> in <module>()
# ----> 1 X_test[3018]
#
# IndexError: index 3018 is out of bounds for axis 0 with size 65

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-2.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 19s 32ms/step
# 67/67 [==============================] - 2s 31ms/step
# 65/65 [==============================] - 2s 30ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[620])
plt.show()
imshow(np.squeeze(Y_train[60]))
plt.show()
imshow(np.squeeze(preds_train_t[60]))
plt.show()
# Out:
# /home/mb/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/mb/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# /home/mb/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/mb/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-2.csv', index=False)

# %%
f1

test_ids = next(os.walk(TEST_PATH))[1]

out_file = open("stage2_test_final.txt", "w")

for path, dirs, files in os.walk('./doesnt-exist'):
    dirs = sorted(dirs)
    out_file.write(im_path+"\n")
    break

out_file = open("stage2_test_final.txt", "w")

for n, id_ in enumerate(test_ids):
    im_path =  TEST_PATH + id_ + '/images/' + id_ + '.png'
    out_file.write(im_path+"\n")

image_ids = check_output(["ls", "../input/stage2_test_final/"]).decode("utf8").split()

f = open("stage2_test_final.txt", "r")

f1 = f.read()

for x in f1:
    test_id2 = x

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []

len(test_ids)
# Out:
# '../input/stage2_test_final/0019c086029dd3be01f72131edb74e21ee995574e6d5c136ea868630b0d73523/images/0019c086029dd3be01f72131edb74e21ee995574e6d5c136ea868630b0d73523.png\n../input/stage2_test_final/004a078bb44ee55ee7d6f1c19f96b3a0d3b5037746a3a75197dbb0be06da05cf/images/004a078bb44ee55ee7d6f1c19f96b3a0d3b5037746a3a75197dbb0be06da05cf.png\n../input/stage2_test_final/005463e6d4a0a0b21161f1d97392f22556fbddba970d9440ae774229308a91ed/images/005463e6d4a0a0b21161f1d97392f22556fbddba970d9440ae774229308a91ed.png\n../input/stage2_test_final/005af293e8e53218ae96746ecf9bb88b511154d4a0b35e4ec6296b4623e15836/images/005af293e8e53218ae96746ecf9bb88b511154d4a0b35e4ec6296b4623e15836.png\n../input/stage2_test_final/005d47447abac7f7fa0ac56ba82f13edbf485105baf0672504d84b58d562f38b/images/005d47447abac7f7fa0ac56ba82f13edbf485105baf0672504d84b58d562f38b.png\n../input/stage2_test_final/00ac87390253a22f6eb67c5771a73050e06200d1aa682fcf1b1e3783b2944166/images/00ac87390253a22f6eb67c5771a73050e06200d1aa682fcf1b1e3783b2944166.png\n../input/stage2_test_final/00b4b9c026cfc91af21691503bad67081fc02d5c77b3cd27200d02dca6966b83/images/00b4b9c026cfc91af21691503bad67081fc02d5c77b3cd27200d02dca6966b83.png\n../input/stage2_test_final/00da4fe5346bbb36ccf178964a22fdf7e33888989624176a6af3b4a7cfd7da63/images/00da4fe5346bbb36ccf178964a22fdf7e33888989624176a6af3b4a7cfd7da63.png\n../input/stage2_test_final/00e36f2470960e84cfc9f0d30c1f76abd7b35e4516380bf